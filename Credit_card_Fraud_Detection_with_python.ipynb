# %% [markdown]
# Importing The Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
import seaborn as sns
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %%
#loading the dataset to a pandas dataframe
credit_card_data=pd.read_csv('/content/creditcard.csv')

# %%
#find the first 10 rows data of the dataset
credit_card_data.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5     2 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6     4  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7     7 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8     7 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9     9 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
#find the 10 rows data last in dataset
credit_card_data.tail(10)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 13944  24743  1.232359  0.026959  0.395652  0.881207 -0.163071  0.077109
# 13945  24748  1.279499 -1.157283  0.466173 -1.026907 -1.501706 -0.906143
# 13946  24749  1.061662 -0.465585  1.226568  0.253467 -0.753072  0.919268
# 13947  24750  1.144993  0.024042  0.748719  1.001344 -0.629653 -0.481646
# 13948  24753 -0.565780  0.754977  0.737825  0.030154 -1.383391  0.268107
# 13949  24754  1.252924 -0.182189 -0.802716 -0.210981  1.916713  3.643624
# 13950  24756 -0.346979 -2.103284 -0.685061  1.961605 -0.401125  0.473632
# 13951  24759 -6.053652 -5.988723  0.810413 -0.011811  1.308135 -0.590803
# 13952  24759  1.169121 -1.284945  0.032717 -0.681670  0.660598  4.412578
# 13953  24759 -6.917152  5.854171 -1.652458 -1.488884 -0.833891 -0.344418
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 13944 -0.308653  0.043007  2.011372  ... -0.408830 -0.779233  0.007874
# ...

# %%
#find the information about the data
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13954 entries, 0 to 13953
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    13954 non-null  int64
#  1   V1      13954 non-null  float64
#  2   V2      13954 non-null  float64
#  3   V3      13954 non-null  float64
#  4   V4      13954 non-null  float64
#  5   V5      13954 non-null  float64
#  6   V6      13954 non-null  float64
#  7   V7      13954 non-null  float64
#  8   V8      13954 non-null  float64
#  9   V9      13954 non-null  float64
#  10  V10     13954 non-null  float64
#  11  V11     13954 non-null  float64
#  12  V12     13954 non-null  float64
#  13  V13     13954 non-null  float64
#  14  V14     13954 non-null  float64
#  15  V15     13954 non-null  float64
#  16  V16     13954 non-null  float64
#  17  V17     13954 non-null  float64
#  18  V18     13954 non-null  float64
#  19  V19     13954 non-null  float64
# ...

# %%
#checking the missing value of the dataset
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    1
# Class     1
# dtype: int64

# %%
#Distribution of  legit transactions and fraudulent  transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    13897
# 1.0       56
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0------> Normal Transactions
#
#
# 1------. fradulent Transactions

# %%
#seperating the data for the analysis
legit=credit_card_data[credit_card_data.Class==0]
fraud=credit_card_data[credit_card_data.Class==1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (13897, 31)
# (56, 31)

# %%
#statistical measure of the dataset
credit_card_data.describe()
# Out:
#                Time            V1            V2            V3            V4  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean   10121.161817     -0.235676      0.284287      0.846047      0.302775
# std     7739.625811      1.720315      1.394804      1.561376      1.500595
# min        0.000000    -27.670569    -34.607649    -24.667741     -4.657545
# 25%     2984.250000     -0.969786     -0.282728      0.407297     -0.623141
# 50%     9086.500000     -0.319439      0.252904      0.960978      0.220104
# 75%    17103.500000      1.162662      0.884741      1.607031      1.198942
# max    24759.000000      1.960497     10.558600      4.101716     11.927512
#
#                  V5            V6            V7            V8            V9  \
# count  13954.000000  13954.000000  13954.000000  13954.000000  13954.000000
# mean      -0.118730      0.128013     -0.157297     -0.016148      0.989827
# ...

# %%
legit.Amount.describe()
# Out:
# count    13897.000000
# mean        63.773909
# std        177.164503
# min          0.000000
# 25%          5.770000
# 50%         15.900000
# 75%         52.370000
# max       7712.430000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      56.000000
# mean       90.815893
# std       310.308450
# min         0.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.025000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare  the values for both Transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10111.481255 -0.217093  0.266252  0.887227  0.276789 -0.107510
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.136745 -0.131462 -0.020385  1.005460  ...  0.020758 -0.068686
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.158230 -0.034834  0.013065  0.117928  0.034349  0.009565  0.002329
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    63.773909
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %% [markdown]
# Under_Sampling

# %% [markdown]
# Build A sample dataset containing similar Distribution of normal Transactions and fraudulent Transactions

# %% [markdown]
# normal_Transactions------13897
#
# Fraudulent_transactions------56

# %%
legit_sample=legit.sample(n=56)

# %% [markdown]
# Concatenating two dataframe

# %%
new_dataset=pd.concat([legit_sample,fraud],axis=0)

# %%
print(new_dataset)
# Out:
#         Time         V1         V2         V3         V4         V5        V6  \
# 5215    4995  -2.459494   2.294589   0.418490  -1.427252  -0.973346 -0.921087
# 7778   10833  -1.969209   0.213785  -0.661860  -1.215319  -5.454503  3.129891
# 624      472   1.040781   0.109569   0.357987   1.118998  -0.105373 -0.056837
# 1448    1124   1.032034  -0.690951  -0.564275  -1.474237  -0.494574 -1.149673
# 3797    3307  -1.127687   0.409140   1.882322  -0.140129   0.169928 -0.723562
# ...      ...        ...        ...        ...        ...        ...       ...
# 11880  20451 -15.819179   8.775997 -22.804686  11.864868  -9.092361 -2.386893
# 12070  20931 -16.367923   9.223692 -23.270631  11.844777  -9.462037 -2.450444
# 12108  21046 -16.917468   9.669900 -23.736443  11.824990  -9.830548 -2.514829
# 12261  21419 -17.467710  10.114816 -24.202142  11.805469 -10.198046 -2.579938
# 12369  21662 -18.018561  10.558600 -24.667741  11.786180 -10.564657 -2.645681
#
# ...

# %%
new_dataset.head(10)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 5215    4995 -2.459494  2.294589  0.418490 -1.427252 -0.973346 -0.921087
# 7778   10833 -1.969209  0.213785 -0.661860 -1.215319 -5.454503  3.129891
# 624      472  1.040781  0.109569  0.357987  1.118998 -0.105373 -0.056837
# 1448    1124  1.032034 -0.690951 -0.564275 -1.474237 -0.494574 -1.149673
# 3797    3307 -1.127687  0.409140  1.882322 -0.140129  0.169928 -0.723562
# 380      279 -0.857063  0.204627  2.186985 -0.045589  0.472689 -0.187450
# 3583    3065 -0.521762  0.626184 -0.599239 -3.271827  2.656585  2.747355
# 11731  20063  1.127497 -0.470724  1.087847 -0.616540 -1.131647 -0.130339
# 1434    1111  1.132691 -0.099536  1.006702  0.526097 -0.753368 -0.169313
# 9294   13445  1.213253  0.088066  1.023482  0.227933 -0.775637 -0.664523
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 5215  -0.274844  0.762272  2.323468  ... -0.418279 -0.482228  0.092917
# ...

# %%
new_dataset.tail(10)
# Out:
#         Time         V1         V2         V3         V4         V5        V6  \
# 10891  18675 -12.339603   4.488267 -16.587073  10.107274 -10.420199  0.130670
# 10897  18690 -15.398845   7.472324 -19.026912  11.165526  -6.893856 -2.120937
# 11343  19762 -14.179165   7.421370 -21.405836  11.927512  -7.974281 -2.202710
# 11710  20011 -14.724627   7.875157 -21.872317  11.906170  -8.348734 -2.262846
# 11841  20332 -15.271362   8.326581 -22.338591  11.885313  -8.721334 -2.324307
# 11880  20451 -15.819179   8.775997 -22.804686  11.864868  -9.092361 -2.386893
# 12070  20931 -16.367923   9.223692 -23.270631  11.844777  -9.462037 -2.450444
# 12108  21046 -16.917468   9.669900 -23.736443  11.824990  -9.830548 -2.514829
# 12261  21419 -17.467710  10.114816 -24.202142  11.805469 -10.198046 -2.579938
# 12369  21662 -18.018561  10.558600 -24.667741  11.786180 -10.564657 -2.645681
#
#               V7        V8        V9  ...       V21       V22       V23  \
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    56
# 1.0    56
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    10613.410714 -0.105276  0.078564  0.875292  0.637070  0.069083
# 1.0    12262.107143 -4.727948  4.660436 -9.328536  6.783464 -2.890388
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.210702 -0.021475  0.067982  1.022155  ...  0.061819 -0.159286
# 1.0   -2.030360 -6.578337  1.028374 -2.981468  ...  0.453283  0.116896
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.089480 -0.039127  0.178916  0.173751  0.058290  0.030581 -0.056930
# 1.0    0.048132 -0.225526 -0.452514 -0.124184  0.333325  0.793484 -0.046177
#
#           Amount
# Class
# 0.0    79.967500
# 1.0    90.815893
#
# [2 rows x 30 columns]

# %% [markdown]
# Splitting the data in to features and Target

# %%
x=new_dataset.drop(columns='Class',axis=1)
y=new_dataset['Class']

# %%
print(x)
print(y)
# Out:
#         Time         V1         V2         V3         V4         V5        V6  \
# 5215    4995  -2.459494   2.294589   0.418490  -1.427252  -0.973346 -0.921087
# 7778   10833  -1.969209   0.213785  -0.661860  -1.215319  -5.454503  3.129891
# 624      472   1.040781   0.109569   0.357987   1.118998  -0.105373 -0.056837
# 1448    1124   1.032034  -0.690951  -0.564275  -1.474237  -0.494574 -1.149673
# 3797    3307  -1.127687   0.409140   1.882322  -0.140129   0.169928 -0.723562
# ...      ...        ...        ...        ...        ...        ...       ...
# 11880  20451 -15.819179   8.775997 -22.804686  11.864868  -9.092361 -2.386893
# 12070  20931 -16.367923   9.223692 -23.270631  11.844777  -9.462037 -2.450444
# 12108  21046 -16.917468   9.669900 -23.736443  11.824990  -9.830548 -2.514829
# 12261  21419 -17.467710  10.114816 -24.202142  11.805469 -10.198046 -2.579938
# 12369  21662 -18.018561  10.558600 -24.667741  11.786180 -10.564657 -2.645681
#
# ...

# %% [markdown]
# Seperating the data Training data and test data

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,stratify=y,random_state=2)

# %%
print(x.shape,x_train.shape,x_test.shape)
# Out:
# (112, 30) (89, 30) (23, 30)

# %% [markdown]
# Model Training

# %% [markdown]
# Logistic Regression

# %%
model=LogisticRegression()

# %%
#training the Logistics Regression model with Training data
model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %% [markdown]
# Accuracy_score

# %%
#accuracy_score on the training_ data
x_train_prediction=model.predict(x_train)
training_data_accuracy=accuracy_score(x_train_prediction,y_train)

# %%
print('Accuracy on the Training data',training_data_accuracy)
# Out:
# Accuracy on the Training data 0.9887640449438202

# %%
#accuracy_ score on the test data
x_test_prediction=model.predict(x_test)
test_data_accuracy=accuracy_score(x_test_prediction,y_test)

# %%
print('Accuarcy score on the test data',test_data_accuracy)
# Out:
# Accuarcy score on the test data 1.0
